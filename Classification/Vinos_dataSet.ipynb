# %% [markdown]
# # Data set vinos
#
# Aca lo que vamos a demostrar es como graficar los valores que tenemos
# con el dataset de los vinos, este dataset nos va ayudar a entender mas
# la clasificacion de la data en el grafico

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import MinMaxScaler

# %%
wine = load_wine()

wine.target_names, wine.feature_names
# Out:
# (array(['class_0', 'class_1', 'class_2'], dtype='<U7'),
#  ['alcohol',
#   'malic_acid',
#   'ash',
#   'alcalinity_of_ash',
#   'magnesium',
#   'total_phenols',
#   'flavanoids',
#   'nonflavanoid_phenols',
#   'proanthocyanins',
#   'color_intensity',
#   'hue',
#   'od280/od315_of_diluted_wines',
#   'proline'])

# %%
wine.data
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]], shape=(178, 13))

# %%
x = range(0, wine.data.shape[0],1)

scaler = MinMaxScaler()
scaler.fit(wine.data)
wine_scaled = scaler.transform(wine.data)

wine_scaled
# Out:
# array([[0.84210526, 0.1916996 , 0.57219251, ..., 0.45528455, 0.97069597,
#         0.56134094],
#        [0.57105263, 0.2055336 , 0.4171123 , ..., 0.46341463, 0.78021978,
#         0.55064194],
#        [0.56052632, 0.3201581 , 0.70053476, ..., 0.44715447, 0.6959707 ,
#         0.64693295],
#        ...,
#        [0.58947368, 0.69960474, 0.48128342, ..., 0.08943089, 0.10622711,
#         0.39728959],
#        [0.56315789, 0.36561265, 0.54010695, ..., 0.09756098, 0.12820513,
#         0.40085592],
#        [0.81578947, 0.66403162, 0.73796791, ..., 0.10569106, 0.12087912,
#         0.20114123]], shape=(178, 13))

# %%
def plot(init_feature,end_feature, mark):
    plt.figure(figsize=(30,5))
    for i in range(init_feature,end_feature,1):
        plt.plot(x, wine_scaled[:,i],mark, label=wine.feature_names[i])
    
    plt.rcParams.update({'font.size': 18})
    plt.legend(prop={'size':22}); plt.grid()
    plt.show()


plot(0,4,'-')
plot(4,8, 'o')
plot(8,12, '^')
